# %%
import psycopg2
import os
import pandas as pd
import matplotlib as plt

# %%
conn = psycopg2.connect(
    host=os.environ.get("POSTGRES_HOST"),
    database=os.environ.get("POSTGRES_DB"),
    user=os.environ.get("POSTGRES_USER"),
    password=os.environ.get("POSTGRES_PASSWORD")
)

# %%
wirbelj_relab = pd.read_sql("SELECT * FROM wirbelj_relab", conn)
vogtmanne_relab = pd.read_sql("SELECT * FROM vogtmanne_relab", conn)
# Out:
# /tmp/ipykernel_15812/2089965804.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   wirbelj_relab = pd.read_sql("SELECT * FROM wirbelj_relab", conn)
# /tmp/ipykernel_15812/2089965804.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   vogtmanne_relab = pd.read_sql("SELECT * FROM vogtmanne_relab", conn)

# %% [markdown]
# I want to get an understanding of how the data looks like. Preferably I want to find out if there are outlier taxa or samples which may skew models.

# %%
# First map out averge total abundance of each data set for each sample.
wirbelj_relab['total_ab'] = wirbelj_relab.iloc[:,:-2].sum(axis=1)

# %%
wirbelj_relab_sorted = wirbelj_relab.sort_values(by=['total_ab'], ascending=False).iloc[:, -3:]

# %%
wirbelj_relab_sorted
# Out:
#             Sample_name  disease   total_ab
# 33  CCMD32288175ST-11-0  healthy  100.00005
# 10  CCMD18829815ST-11-0  healthy  100.00003
# 69  CCMD53522274ST-11-0  healthy  100.00003
# 28  CCMD29706695ST-11-0  healthy  100.00001
# 89  CCMD74592084ST-11-0  healthy  100.00001
# ..                  ...      ...        ...
# 61  CCMD50529145ST-11-0  healthy   97.59393
# 32  CCMD31134579ST-11-0  healthy   97.48468
# 57  CCMD49461418ST-11-0      CRC   97.27017
# 93  CCMD76409700ST-11-0  healthy   96.63202
# 92  CCMD76222476ST-11-0      CRC   95.75848
#
# [125 rows x 3 columns]
