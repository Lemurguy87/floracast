# %%
# Test loading WirbelJ data
import psycopg2
import os
import pandas as pd

# %%
conn = psycopg2.connect(
    host=os.environ.get("POSTGRES_HOST"),
    database=os.environ.get("POSTGRES_DB"),
    user=os.environ.get("POSTGRES_USER"),
    password=os.environ.get("POSTGRES_PASSWORD")
)

# %%
df = pd.read_sql("""
    SELECT table_name 
    FROM information_schema.tables 
    WHERE table_schema = 'public'
""", conn)
# Out:
# /tmp/ipykernel_91/2076558290.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql("""

# %%
wiberlj_taxa = pd.read_sql("SELECT * FROM wirbel_taxa", conn)
print(wiberlj_taxa.head(1))
# Out:
#    id          sample_name class  faecalibacterium_prausnitzii  \
# 0   1  WirbelJ_2018_CRC_P1   CRC                       0.28804
#
#    bacteroides_uniformis  alistipes_putredinis  phocaeicola_vulgatus  \
# 0                 18.399               5.26533               5.38122
#
#    roseburia_intestinalis  roseburia_inulinivorans  \
# 0                 0.03172                  0.79898
#
#    fusicatenibacter_saccharivorans  ...  mitsuokella_sp_oral_taxon_131  \
# 0                          0.53782  ...                            0.0
#
#    propionibacterium_acidifaciens  negativicoccus_succinicivorans  \
# 0                             0.0                             0.0
#
#    desulfovibrio_sp_mes5  lactococcus_piscium  butyricicoccus_pullicaecorum  \
# 0                    0.0                  0.0                           0.0
#
#    streptococcus_agalactiae  tropheryma_whipplei  cutibacterium_acnes  \
# 0                       0.0                  0.0                  0.0
#
#    actinomyces_sp_oral_taxon_414
# 0                            0.0
#
# [1 rows x 532 columns]
# /tmp/ipykernel_91/269292917.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   wiberlj_taxa = pd.read_sql("SELECT * FROM wirbel_taxa", conn)
