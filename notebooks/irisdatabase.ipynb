# %%
#Access database in seperate container
import psycopg2
import os
import pandas as pd

# %%
conn = psycopg2.connect(
    host=os.environ.get("POSTGRES_HOST"),
    database=os.environ.get("POSTGRES_DB"),
    user=os.environ.get("POSTGRES_USER"),
    password=os.environ.get("POSTGRES_PASSWORD")
)

# %%
# Check what tables exist
df = pd.read_sql("""
    SELECT table_name 
    FROM information_schema.tables 
    WHERE table_schema = 'public'
""", conn)
print("Tables:", df)

iris_df = pd.read_sql("SELECT * FROM iris", conn)
print(iris_df)
# Out:
# Tables:   table_name
# 0       iris
#    id  sepal_length  sepal_width  petal_length  petal_width     species
# 0   1           5.1          3.5           1.4          0.2      setosa
# 1   2           4.9          3.0           1.4          0.2      setosa
# 2   3           4.7          3.2           1.3          0.2      setosa
# 3   4           7.0          3.2           4.7          1.4  versicolor
# 4   5           6.4          3.2           4.5          1.5  versicolor
# 5   6           6.9          3.1           4.9          1.5  versicolor
# 6   7           6.3          3.3           6.0          2.5   virginica
# 7   8           5.8          2.7           5.1          1.9   virginica
# 8   9           7.1          3.0           5.9          2.1   virginica
# /tmp/ipykernel_118/2226971467.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql("""
# /tmp/ipykernel_118/2226971467.py:9: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   iris_df = pd.read_sql("SELECT * FROM iris", conn)
